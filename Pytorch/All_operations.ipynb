# %% [markdown]
# ## 1) What is PyTorch?
# PyTorch is a deep learning framework built around tensors and automatic differentiation. It provides:
# - Tensors with GPU acceleration
# - Autograd for automatic gradients
# - Modules for building neural networks
# - Optimizers and training utilities

# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cpu

# %% [markdown]
# ## 2) Tensors and basic creation
# Tensors are n-dimensional arrays. You can create them from lists, NumPy arrays, or with helpers.

# %%
import torch

# Scalars, vectors, matrices
scalar = torch.tensor(3.14)
vector = torch.tensor([1.0, 2.0, 3.0])
matrix = torch.tensor([[1, 2], [3, 4]])

print(scalar, scalar.shape)
print(vector, vector.shape)
print(matrix, matrix.shape)

# Common initializations
zeros = torch.zeros((2, 3))
ones = torch.ones((2, 3))
rand = torch.rand((2, 3))

print(zeros)
print(ones)
print(rand)
# Out:
# tensor(3.1400) torch.Size([])
# tensor([1., 2., 3.]) torch.Size([3])
# tensor([[1, 2],
#         [3, 4]]) torch.Size([2, 2])
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# tensor([[0.4658, 0.7148, 0.0962],
#         [0.9421, 0.4988, 0.0600]])

# %% [markdown]
# ## 3) Tensor attributes and device
# Tensors carry dtype and device (CPU/GPU). Use `.to(device)` to move them.

# %%
x = torch.randn(3, 3, dtype=torch.float32)
print(x.dtype, x.device)

# If CUDA is available, move to GPU
if torch.cuda.is_available():
    x = x.to('cuda')
    print('moved to', x.device)
# Out:
# torch.float32 cpu

# %% [markdown]
# ## 4) Autograd basics
# Autograd tracks operations on tensors with `requires_grad=True` so gradients can be computed.

# %%
from numpy import gradient


w = torch.tensor(2.0, requires_grad=True)

x = torch.tensor(3.0, requires_grad=True) # mentioned requires_grad = True if you want to compute gradients with respect to this tensor
y = w * x**2 + 1

# Backprop
y.backward() # compute the derivative at x=3 dy/dx
print('y:', y.item())
x_grad = x.grad
print('dy/dx:', x_grad) 
print('dy/dw:', w.grad)
# Out:
# y: 19.0
# dy/dx: tensor(12.)
# dy/dw: tensor(9.)

# %% [markdown]
# ## 5) Building a simple model
# Use `nn.Module` to define models and `nn.Linear` for linear layers.

# %%
import torch.nn as nn

class SimpleLinear(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Linear(1, 1)

    def forward(self, x):
        return self.layer(x)

model = SimpleLinear()
print(model)
# Out:
# SimpleLinear(
#   (layer): Linear(in_features=1, out_features=1, bias=True)
# )

# %% [markdown]
# ## 6) Loss and optimizer
# Loss functions measure prediction error and optimizers update parameters.

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# Dummy data
X = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
Y = torch.tensor([[2.0], [4.0], [6.0], [8.0]])

# Forward pass
preds = model(X)
loss = criterion(preds, Y)
print('loss:', loss.item())

# Backward + update
optimizer.zero_grad()
loss.backward()
optimizer.step()
# Out:
# loss: 30.416828155517578

# %% [markdown]
# ## 7) Training loop example (linear regression)
# A full training loop ties together forward, loss, backward, and update.

# %%
model = SimpleLinear()
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for epoch in range(50):
    preds = model(X)
    loss = criterion(preds, Y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'epoch {epoch+1}: loss={loss.item():.4f}')
# Out:
# epoch 10: loss=0.0608
# epoch 20: loss=0.0231
# epoch 30: loss=0.0126
# epoch 40: loss=0.0068
# epoch 50: loss=0.0037

# %% [markdown]
# ## 8) Saving and loading models
# Persist the model weights with `state_dict`.

# %%
# Save
path = 'simple_linear.pt'
torch.save(model.state_dict(), path)

# Load
loaded = SimpleLinear()
loaded.load_state_dict(torch.load(path, map_location='cpu'))
loaded.eval()
print('loaded ok')
# Out:
# loaded ok

# %% [markdown]
# ## 9) Mini exercise
# - Create a 2-layer MLP with ReLU.
# - Train it to fit a small synthetic dataset (e.g., y = x^2).
# - Print loss every 20 epochs.

# %%
class MultiLayerPerceptron(nn.Module):
    def __init__(self, in_features, hidden_units, num_layers=1):
        super().__init__()
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(in_features, hidden_units))
        for _ in range(num_layers - 1):
            self.layers.append(nn.Linear(hidden_units, hidden_units))
        self.layers.append(nn.Linear(hidden_units, 1))  # single logit

    def forward(self, x):
        for layer in self.layers[:-1]:
            x = torch.relu(layer(x))
        x = self.layers[-1](x)  # logits
        return x

model = MultiLayerPerceptron(in_features=10, hidden_units=32, num_layers=2)
loss = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

from torchinfo import summary

summary(model, input_size=(64, 10))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MultiLayerPerceptron                     [64, 1]                   --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [64, 32]                  352
# │    └─Linear: 2-2                       [64, 32]                  1,056
# │    └─Linear: 2-3                       [64, 1]                   33
# ==========================================================================================
# Total params: 1,441
# Trainable params: 1,441
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.09
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.04
# ==========================================================================================

# %%
# Dummy data
X = torch.randn(64, 10)  # example input
y = torch.randint(0, 2, (64, 1)).float()  # example binary labels
# initial weight
# print(list(model.parameters())[0])
epochs = 100
losses = []
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X)
    loss_value = loss(outputs, y)
    print(loss_value)
    loss_value.backward()
    optimizer.step()
    losses.append(loss_value.item())
# Out:
# tensor(1.0555, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.0494, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.0359, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.0170, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.9942, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.9688, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.9416, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.9136, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8854, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8576, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8308, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8052, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7808, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7577, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7362, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7161, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6972, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6793, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6626, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6469, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6324, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6186, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6057, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5936, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5825, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5720, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5622, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5530, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5444, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5363, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5286, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5213, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5142, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5073, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5007, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4943, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4880, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4819, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4758, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4699, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4642, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4585, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4530, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4476, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4424, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4372, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4321, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4271, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4221, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4172, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4123, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4076, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4029, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3982, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3937, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3893, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3849, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3807, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3765, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3724, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3683, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3643, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3603, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3563, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3524, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3486, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3448, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3412, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3376, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3340, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3305, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3271, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3236, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3202, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3168, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3134, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3100, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3067, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3034, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3002, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2970, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2937, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2905, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2873, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2841, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2810, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2780, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2750, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2720, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2691, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2661, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2631, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2602, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2573, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2544, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2515, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2487, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2459, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2431, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.2403, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)

# %%
from matplotlib import pyplot as plt


plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.show()
