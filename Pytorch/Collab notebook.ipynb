# %%
import torch
import torch as nn
import torch.optim as optim

# %%
# Each row = one email
# Features: [free_word, money_word, link_present, length]
X = torch.tensor([
    [1, 1, 1, 300],   # spam
    [0, 0, 0, 120],   # not spam
    [1, 0, 1, 250],   # spam
    [0, 1, 0, 100],   # not spam
    [1, 1, 0, 280],   # spam
    [0, 0, 0, 90],    # not spam
], dtype=torch.float32)

y = torch.tensor([
    [1],
    [0],
    [1],
    [0],
    [1],
    [0]
], dtype=torch.float32)
